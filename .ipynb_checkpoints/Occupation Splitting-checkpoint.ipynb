# %%
import pandas as pd

# %%
# Filepath
user_data_fp = 'twitter_data/NEW_Coded_Bios_and_Labels0229.xlsx'
network_data_fp = 'twitter_data/network.xlsx'

# %%
# Dataframe
user_data_df = pd.read_excel(user_data_fp)
network_data_df = pd.read_excel(network_data_fp)

# %%
user_data_df
# Out:
#          screen_name                                        description  \
# 0             _aedye  Plant viruses and vectors, food security, scie...
# 1         _akiraendo  Infectious disease modeller (MD PhD). JSPS Res...
# 2        _CleoKrejci  The sun's not yellow, it's chicken._x000D_\n_x...
# 3        _decolonise  Decolonial Subversions is an open access, mult...
# 4          _evelienc  (copy)writes |(end)edits | creates content(eme...
# ...              ...                                                ...
# 1995         Zikarr_  Christian and Saved! | Public Health | Communi...
# 1996           ZLabe  Climate Scientist (Atmospheric) PhD | Postdoc ...
# 1997  ZombieScholars  The Zombie Scholars Academy is a summer academ...
# 1998      ZTPetrizzo  media & politics reporter @thedailybeast._x000...
# 1999   ZulmaCucunuba  Infectious Disease Epidemiologist, MD PhD | As...
#
#           New_Aggregate_Labels New_Aggregate_Labels.1 New_Aggregate_Labels.2  \
# 0                      Student                    NaN                    NaN
# 1                    Scientist                    NaN                    NaN
# 2           Media practitioner                    NaN                    NaN
# 3           Media organisation                    NaN                    NaN
# 4        Cultural professional                    NaN                    NaN
# ...                        ...                    ...                    ...
# 1995          Non classifiable                    NaN                    NaN
# 1996                 Scientist                    NaN                    NaN
# 1997  Educational organisation                    NaN                    NaN
# 1998        Media practitioner                    NaN                    NaN
# 1999                 Scientist              Physician                    NaN
#
#      New_Aggregate_Labels.3 New_Aggregate_Labels.4
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
# ...                     ...                    ...
# 1995                    NaN                    NaN
# 1996                    NaN                    NaN
# 1997                    NaN                    NaN
# 1998                    NaN                    NaN
# 1999                    NaN                    NaN
#
# [2000 rows x 7 columns]

# %%
len(network_data_df[network_data_df['Relationship_type'] == 'Tweet'])
# Out:
# 45999

# %%
user_data_df['New_Aggregate_Labels'].unique()
# Out:
# array(['Student', 'Scientist', 'Media practitioner', 'Media organisation',
#        'Cultural professional', 'Scholar', 'Business professional',
#        'Advocate', 'Politician', 'Non classifiable',
#        'Health professional', 'Physician', 'Charity',
#        'Educational organisation', 'Professional organisation',
#        'Educational professional', 'Health organisation',
#        'Public official', 'Business organisation', 'Policy professional',
#        'Environmental organisation', 'Service organisation',
#        'PR professional', 'Activist', 'Legal professional',
#        'research organisation', 'Cultural organisation', 'Athlete',
#        'Office worker', 'Philanthropist', 'Technology professional',
#        'Government organisation', 'Development professional',
#        'Physical trainer', 'Social worker', 'Political organisation',
#        'Disabled', 'Economist', 'Policy organisation', 'Illness survivor',
#        'Government Organisation', 'Sports organisation', 'Scientist  ',
#        'Event', 'Researcher', 'Service worker',
#        'Environmental professional', 'Trade worker',
#        'Student organisation', 'Volunteer', 'Military member', 'Retired'],
#       dtype=object)

# %%
# Occupation Groups
# Group 1: Education and Research
education_labels = [
    'Student', 'Scholar', 'Educational professional', 'Educational organisation'
]

# Group 2: Media and Communication
media_labels = [
    'Media practitioner', 'Media organisation', 'PR professional'
]

# Group 3: Health and Medicine
medicine_and_research_labels = [
    'Health professional', 'Physician', 'Health organisation', 'Researcher', 'Scientist', 'Scientist  ', 'Research organisation'
]

# Group 4: Government and Politics
civic_labels = [
    'Politician', 'Public official', 'Policy professional', 'Policy organisation',
    'Government organisation', 'Government Organisation', 'Political organisation'
]

# Group 5: Business and Professional Services
business_labels = [
    'Business professional', 'Business organisation', 'Professional organisation', 'Technology professional', 'Development professional',
    'Service organisation'
]

# Group 6: Advocacy and Non-profits
advocacy_nonprofits_labels = [
    'Advocate', 'Charity', 'Philanthropist', 'Activist',
    'Volunteer', 'Social worker', 'Environmental organisation', 'Environmental professional'
]

# Group 7: Culture and Sports
culture_sports_labels = [
    'Cultural professional', 'Cultural organisation', 'Athlete',
    'Sports organisation', 'Physical trainer', 'Event'
]

# Group 8: Miscellaneous
miscellaneous_labels = [
    'Student organisation', 'PR professional', 'Disabled', 'Economist',
    'Trade worker', 'Military member', 'Retired', 'Illness survivor', 'Service worker', 'Office worker', 'Legal professional', 'Non classifiable',
]
