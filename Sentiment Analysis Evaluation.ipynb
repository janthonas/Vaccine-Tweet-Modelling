# %%
# Pre-Processing
import pandas as pd
import re
import emoji
import contractions

# Machine Learning
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import torch

# %% [markdown]
# ## Import Dataset

# %%
test_data_fp = 'twitter_data/custom_data/COVIDSenti-main/COVIDSenti-A.csv'

# %%
test_data_df = pd.read_csv(test_data_fp)

# %%
test_data_df = test_data_df.head(500)

# %%
test_data_df
# Out:
#                                                  tweet label
# 0    Coronavirus | Human Coronavirus Types | CDC ht...   neu
# 1    @shehryar_taseer That’s 💯 true , \nCorona...   neu
# 2    TLDR: Not SARS, possibly new coronavirus. Diff...   neg
# 3    Disease outbreak news from the WHO: Middle Eas...   neu
# 4    China - Media: WSJ says sources tell them myst...   neu
# ..                                                 ...   ...
# 495  @realDonaldTrump is the American coronavirus o...   neu
# 496  New coronavirus not yet a global health concer...   neu
# 497  Wuhan, China, shutting down transportation to ...   neg
# 498  @DomenickBeskos Wuhan population 11 million Ch...   neg
# 499  US forces passengers from Wuhan, China to get ...   neu
#
# [500 rows x 2 columns]

# %% [markdown]
# ## Preprocessing

# %%
# Gathering documents
docs = test_data_df['tweet'].tolist()
pruned_docs = docs

# %%
# Removal of links
def remove_urls(doc):
    return re.sub(r'http\S+', '', doc)

pruned_docs = [remove_urls(doc) for doc in pruned_docs]

def convert_emojis(doc):
    # delimiters are what is used around the emoji description, in this case spaces are used
    return emoji.replace_emoji(doc, replace='')

pruned_docs = [convert_emojis(doc) for doc in pruned_docs]

def remove_hashtags(doc):
    return doc.replace('#', '')
    #return re.sub(r'#\w+', '', doc)

pruned_docs = [remove_hashtags(doc) for doc in pruned_docs]

def remove_numbers(doc):
    return re.sub(r'\d+', '', doc)

pruned_docs = [remove_numbers(doc) for doc in pruned_docs]

def remove_user_mentions(doc):
    return re.sub(r'@\w+', '', doc)

pruned_docs = [remove_user_mentions(doc) for doc in pruned_docs]

def fix_contractions(doc):
    return contractions.fix(doc)

pruned_docs = [fix_contractions(doc) for doc in pruned_docs]

def remove_punctuation(doc):
    return re.sub(r'[^\w\s]', '', doc)

pruned_docs = [remove_punctuation(doc) for doc in pruned_docs]

def remove_amp(doc):
    return re.sub(r'\bamp\b', '', doc).strip() # strip removes the surrounding white space

pruned_docs = [remove_amp(doc) for doc in pruned_docs]

def remove_special_character_combinations(doc):
    # Remove all combinations of \r and \n in any order
    cleaned_text = re.sub(r'[\r\n\xa0]+', '', doc)
    return cleaned_text
    
pruned_docs = [remove_special_character_combinations(doc) for doc in pruned_docs]

def remove_non_english_characters(doc):
    return re.sub(r'[^\x00-\x7F]+', '', doc)

pruned_docs = [remove_non_english_characters(doc) for doc in pruned_docs]

# %%
pruned_docs
# Out:
# ['Coronavirus  Human Coronavirus Types  CDC',
#  'Thats  true  Corona virus swine flue Bird flu in December when whole Pk is busy in Marriage',
#  'TLDR Not SARS possibly new coronavirus Difficult to confirm because patients identified later in infection when',
#  'Disease outbreak news from the WHO Middle East respiratory syndrome coronavirus MERSCoV  The United Arab Emira',
#  'China  Media WSJ says sources tell them mystery pneumonia is a new coronavirus  something that has been speculat',
#  'The mystery new virus causing China pneumonia outbreak is possibly new coronavirus same family as sars and mers',
#  'Virologists weigh in on novel coronavirus in Chinas outbreak',
#  'Chinese authorities have made a preliminary determination of a novel or new coronavirus identified in a hospit',
#  'Why CCP keep on saying unknown because of pneumonia The because is obviously related to corona virus Let us',
#  'Chinese report says mysterious illnesses may be from new coronavirus',
#  'China identifies new strain of coronavirus as source of pneumonia outbreak',
#  'I always feel weird hoping for another coronavirus outbreak to rationalize our research',
#  'Mystery illness in China traced to new SARSfamily coronavirus CNET',
#  'Wuhan pneumonia outbreak Mystery illness caused by coronavirus  BBC News  via',
#  'CDC health advisory about the Chinese coronavirus outbreak ask patients with severe respiratory disease about trav',
#  'The new coronavirus identified by Chinese scientists is the putative because of an outbreak of unusual',
#  'The Frieman Scary Scale makes its debut Wuhan Coronavirus scores  out of  N masks',
#  'Genome sequence of the new coronavirus associated with a pneumonia cluster in Wuhan China',
#  'Crap a quick blast search suggests the Wuhan coronavirus looks like a Bat SARSlike coronavirus with  identi',
#  'summarises novel coronavirus lab findings',
#  'China reports st death from new type of coronavirus  CBC News',
#  'China Reports First Death From New Coronavirus  Jan    AM ET',
#  'RT  All of the WHO interim guidance and technical documents on novel coronavirus will be updated as needed',
#  'And there it is  a  call for transparency and datasharing concerning WuHanPneumonia coronavirus If it t',
#  'China releases genetic data on new coronavirus now deadly',
#  'New Coronavirus May be Because of Outbreak in China  from',
#  'st baby born pic  Wuhan coronavirus',
#  'Chinas mystery coronavirus is not currently spreading WHO says',
#  'Genetic sequences of the novel coronavirus nCoV will allow countries to develop sp',
#  'Thailand Confirms Traveler from China Hospitalized With New Form of Coronavirus According to YOUN Officials',
#  'Good news on Wuhan coronavirus  rpts outbreak has not spread Seafood market major transport hub is closed no',
#  'Brace yourself America this virus is nasty  its a killer WHO coronavirus China Japan',
#  'Second death reported in Wuhan from Chinas new coronavirussame virus family as SARS  out of Wuhans  patient',
#  'It is likely that the Wuhan outbreak of a novel coronavirus has caused substantially more cases of moderate or sev',
#  'Scientists fear up to  Chinese patients may have caught the newcoronavirus',
#  'Second patient dies from novel coronavirus in China  confirmed case in Japan fears outbreak may have spread fu',
#  'Three YOUS Airports to Screen Passengers for Chinese Coronavirus',
#  'Three YOUS Airports to Screen Passengers for Chinese Coronavirus  nCoV Wuhan',
#  'Three YOUS Airports to Screen Passengers for ChineseCoronavirus',
#  'WHO issues warning after mysterious Chinese coronavirus spreads to Japan',
#  'CDC To Screen For New Strain Of Coronavirus At  YOUS Airports',
#  'YOUS to screen passengers for new China coronavirus at  airports',
#  'CDC To Screen For New Strain Of Coronavirus At  YOUS Airports',
#  'China Wuhan WuhanPneumonia WuhanSARS pneumonia SARS Virus Viral Symptoms Coronavirus Entry Screenings',
#  'Wuhan virus US to screen airline passengers from China amid fear of coronavirusoutbreak',
#  'Coronavirus LAX  other airports to screen airline passengers from China for new illnes  Jan    PM ET',
#  'Japan and Thailand have confirmed cases of a new coronavirus first reported in China raising questions about possi',
#  'Health a new coronavirusinfected pneumonia has been found in China  via',
#  'Novel Coronavirus  Japan exChina nd of  exported cases of novel coronavirus from Wuhan city China Since in',
#  'Wtf is coronavirus',
#  'Wuhan coronavirus sounds trickier than many initially thoughtHas spread to Japan through pp aerial contact to a',
#  'CoronaVirus Where The World Stands As Of Now',
#  'New coronavirus emerging in China some estimates put infected number at more than  people Its more closely',
#  'Ae Coronavirus more cases and second death reported in China',
#  'Three YOUS Airports to Check Passengers for a Deadly Chinese Coronavirus',
#  'China coronavirus at least three suspected cases in Shenzhen Shanghai',
#  'BBC News  New Chinese virus will have infected hundredscoronavirusSars',
#  'CCP China also export WuhanPneumonia coronavirus',
#  'Chinas coronavirus cases likely grossly underestimated study says  CNN',
#  'The number of people already infected by the new coronavirus emerging in',
#  'Any idea what it costs to do the newly developed test for this new coronavirus',
#  'YVR on alert for deadly coronavirus spreading from China',
#  'S Korea reports st confirmed case of China coronavirus',
#  'This Coronavirus seems pretty bad officials are worried it could mutate into the even more potent Modelovirus',
#  'China confirms spread of coronavirus as new cases surge',
#  'BBC News  China coronavirus Number of cases jumps as virus spreads to new cities',
#  'What is this coronavirus again ',
#  'China confirms spread of new coronavirus surge in new infections',
#  'New cases of Coronavirus reported in China',
#  'China coronavirus Number of cases jumps as virus spreads to new cities',
#  'Novel Wuhan coronavirus virus cases leap upLatest blog which does not include  case from Shenzhen and  cases',
#  'Factbox New coronavirus outbreak in Chinese city of Wuhan',
#  'China coronavirus cases surge fuelling fears of major outbreak',
#  'New post What We Know About Chinas New Coronavirus has been published on Trending News',
#  'What We Know About Chinas NewCoronavirus',
#  'Tourists coming to Nepal from the corona virus that is taking epidemic in neighboring China are very likely to',
#  'nCoV China Wuhan coronavirus via',
#  'Mysterious coronavirus cases surge in China as virusspreads',
#  'China coronavirus Beijing breaks its silence but only to deny rumours',
#  'Factbox New coronavirus outbreak spreads in China',
#  'nCoV hh transmission imminent globalspread',
#  'Head of Chinese government expert team confirms humantohuman transmission of new coronavirus state media says',
#  'What We Know About Chinas New Coronavirus  The New York Times  va',
#  'China Coronavirus Outbreak Spreads Hundreds Infected As HumanToHuman Transmission Confirmed  Zero Hedge',
#  'BBC has reported that coronavirus has been detected in Beijing  Shanghai and Shenzhen as well  as Thailan',
#  'pneumonia viral ATUALIZAES NESTE POSTFonte The New York Times china coronavirus news globalbews japao',
#  'Humantohuman transmission of new coronavirus reported in China   News',
#  'China confirms humantohuman transmission of new coronavirus',
#  'China confirms humantohuman transmission of new coronavirus',
#  'cases confirmed But this new virus is not as contagiously SARS said by Dr Zhong infectious disease expert in China coronavirus',
#  'Humantohuman transmission confirmed in China coronavirus WEF globalhealth',
#  'China coronavirus cases surge fuelling fears of major outbreak',
#  'I had the coronavirus last year after drinking about  bottles',
#  'China confirms humantohuman transmission of coronavirus',
#  'South Korea reports first Wuhan coronavirus case  Health',
#  'Do you think if this new coronavirus reaches the US there will be a tougher stance adopted by your aut',
#  'Me hearing this corona virus might be the next plague but I am still a virgin coronavirus',
#  'China Confirms HumanToHuman Transmission As New Coronavirus Jumps AnimalToHuman Barrier Raising Fears Of A Pand',
#  'China confirms new corona virus transmitted by humantohuman contact  National',
#  'China coronavirus WHO to hold emergency meeting as Sarslike virus spreads in Asia',
#  'Brace yourself Global hysteria is comingcoronavirus',
#  'Should the world be worried about the coronavirus in China   Dont Panic Just Yet Folks ',
#  'HumantoHuman transmission coronavirus ChinesePneumonia China Japan',
#  'All the people with their coronavirus puns and jokes Im old so to me Corona means Friday night about pm scre',
#  'As coronavirus spreads to more cities in China WHO calls emergency meeting   wrap tonight ',
#  'Authorities confirm deadly coronavirus spreads by human touch  The New Daily',
#  'Watch out for the coronavirus',
#  'The dog meat trade in China  coronavirus',
#  'China is definitely covering up the coronavirus and not being truthful about the severity of the virus',
#  'Coronavirus In China Over  Cases HumanToHumanTransmission',
#  'China virus extends reach as human transmission is confirmedcoronavirus',
#  'Experts fear latest strain of virus may spread across planet from person to person CoronaVirus China Health',
#  'China confirms mystery coronavirus CAN be transmitted between humans',
#  'HumantoHuman Transmission Confirmed in China CoronavirusFor the latest US and politica',
#  'It has been confirmed that the coronavirus in China is transmitted human to humanwhat is the gover',
#  'Corona virus in China is now known to be contagious  via',
#  'Why are people freaking out about this CoronaVirus It is really not that dangerous influenza will kill more of you this year',
#  'So coronavirus  can be contacted from human Anyways the borders are closed so it cannot enter the kontri ',
#  'What is a coronavirus and why is a new virus strain making people in China so sick  Health  ABC News',
#  'What is a coronavirusSymptomsHow it spreadsTreatmentHow can you can prevent itCoronavirus and pregnancyCorona',
#  'Humantohuman transmission confirmed in China coronavirus',
#  'Should we be getting scared Medics in Hazmat suits screen Air China plane passengers for SARSlike Corona virus',
#  ' Chinese medical workers confirmed infected with coronavirus',
#  'China Confirms New Coronavirus Spreads From Humans to Humans  The New York Times  via',
#  'Re this new coronavirus it does spread persontoperson but SO FAR seems to have a very low mortality rate',
#  'China reports more than  infections with new coronavirus from Wuhan  Science  AAAS',
#  'How Scared Should You Be of The Wuhan Coronavirus',
#  'Bon bah on va tous crever   coronavirus',
#  'The coronavirus has struck  people in Asia most of whom have been in China',
#  'New cases of deadly coronavirus detected in China ahead of busy new year period',
#  'Its a virus a coronavirus   Its not a Racial Group  FFS',
#  'China Confirms New Coronavirus Spreads From Humans to Humans  The New York Times CAIiELePXchbpggBsgh_boqFwgEK',
#  'Coronavirus From where you would rather not be',
#  'Novel Coronavirus  Wuhan China  CDC  via',
#  'are you going to waive the change fees for passengers who want to leave China earlier due to the spreading of novel coronavirus',
#  'What are symptoms of coronavirus and where has it spread',
#  'Humantohuman transmission of coronavirus was confirmed in China Here is what you need to know and video of the ma',
#  'Coronavirus explained What you need to know',
#  'Billy Ray Cyrus Coronavirus',
#  'Corona Virus  Won Ton Soup banned in the YOUS   ',
#  'I read several news articles and I still dont know what the coronavirus is exactly',
#  'BREAKING A Brisbane man is being tested for a new deadly strain of coronavirus after returning from China with a',
#  'A new Chinese coronavirus a cousin of the SARS virus has infected more than  people since the outbreak began i',
#  'The latest K Daily Music News and Tech  Thanks to   opinin coronavirus',
#  'Boston doctor warns about spread of coronavirus',
#  'Everyone should be wary of the coronavirus coming',
#  'World Health Organization to hold an emergency meeting as coronavirus cases rise',
#  'As expected  coming from China  Coronavirus explained What you need to know',
#  'What disease is worse than coronavirus Xenophobia  it is rampant in the UKClassic symptom Make every pr',
#  'Just have a slice of lime if you have the corona virus',
#  'because of the coronavirus in china citizens are advised to wear masks particularly n masks before going outsi',
#  'The newly identified coronavirus killed a third person in China and spread to South Korea The no of cases is now',
#  'China confirms fourth coronavirus death as WHO prepares to meet  News now trending on Monkey Viral ',
#  'Wuhan coronavirus takes fourth life humantohuman transmission confirmed ',
#  'With coronavirus outbreak in China TN asks doctors to look out for influenzalike illnesses reports ',
#  'Fear mounts over China coronavirus outbreak as fourth death reported  via',
#  'China coronavirus claims th life more nations start screening travelers',
#  'Concerns Of Coronavirus Outbreak Prompt SFO To Screen Some Travelers From China  Jan    AM ET',
#  'Top Tendencias de Twitter en  MxicoJan  iKONCoronavirusSwanParty__Malcolm',
#  'Wild animals are likely to be the origin of the new coronavirus that has caused a pneumonia outbreak in Wuhan Hub',
#  'Deadly Corona virus spreading in Asia and Japan',
#  'Nah coronavirus tastes better',
#  'Forex Today Coronavirus spreads to markets BOJ optimistic for a change Trump descends on Davos',
#  'Child from China tests positive for coronavirus in Cebu City',
#  'China Confirms New Coronavirus Spreads From Humans to Humans by BY JAVIER C HERNNDEZ AND AUSTIN RAMZY via NYT N',
#  'Fears of Chinas Coronavirus Prompt Australia to Screen Flights by BY AUSTIN RAMZY via NYT New York Times',
#  'Screening of Wuhan Residents Leaving City Boosted Amid Coronavirus Outbreak  State Media  via',
#  'Yikes CHINA CONFIRMS  CASES OF NEW CORONAVIRUS AS OF JAN CNY CHINA',
#  'DOH Child with China coronavirus admitted in Cebu hospital  Iloilo Today',
#  'The coronavirus continues to spread more dead more infectedAn update will be posted this weekendBBC News ',
#  'They all need to go on a trip to China check out if the coronavirus is real',
#  'what animals can carry Wuhan coronavirus',
#  'coronavirus I can give scientific Nature Cure which can prevent infection of coronavirus and Infect',
#  'Beijing on Tuesday warned cadres not to cover up the spread of the coronavirus saying anyone who puts the face o',
#  'None of which sounds all that creationist James  You need to explain whether YOU think corona virus',
#  'Chinese scientists on January  identified the pathogen as anew strain of coronavirus the same fami',
#  'Nepal at high risk of novel coronavirus',
#  'Child from China tests positive for coronavirus in Cebu City',
#  'An outbreak of a new coronavirus has spread to more Chinese cities including the capital Beijing and Shanghai aut',
#  'Via  China coronavirus claims sixth victim as holiday travel heightens infection risks',
#  'Corona Virus Update  people dead almost  infected as China confirms Wuhan virus can be spread',
#  'The latest The Occupied Herald Sun Daily  Thanks to   coronavirus china',
#  'Chinese coronavirus outbreak has reached the YOUS CDC says',
#  'I have had the corona virus many many times  Mostly in college',
#  'coronavirus ImpeachmentTrialRules Coverup',
#  'what if we just kissed and spread the coronavirushahaha jkunless',
#  'Public Health Alert The coronavirus Has spread out of china into  new countries including The YOUS To help prote',
#  'Everyone has that fancy new Wuhan corona virus they are all talking about',
#  'CDC confirms first YOUS case of China coronavirus',
#  'if corona virus can spread from cats to humans i do not think its the same one though then i have already had it for years',
#  'The coronavirus has landed on YOUS soil mysterious coronavirus from China spread so quickly  MarketWatch',
#  'CDC Announces First YOU S  Case Of Chinese Coronavirus  TheAngryCanuck CDC Coronavirus',
#  'Coronavirus from China has made its way to the United States',
#  'You all need to read up about the new Coronavirus which has already killed  people and is spreading very fast T',
#  'I felt this one in my life everything is real GoodMusic CHEARS meaning coronavirus',
#  'st confirmed case of new coronavirus reported in US CDC',
#  'Hell I have a  pack of Coronavirus in my fridge It only makes you sick if you drink the whole thing',
#  'First confirmed coronavirus case identified in the US',
#  'Washington Man Is st in US to Catch Newly Discovered Viral Pneumonia Get out your face masks folks coronavirus',
#  'me seeing coronavirus trending knowing I never go out do things or have friends',
#  'The United States has its first case of novel coronavirus The man returned from Wuhan China before the US implem',
#  'I believe the WHO needs to declare a state of emergency immediately because of the deadly coronavirus',
#  'sorry but binnie kind of flopping BTSTOUR CHEARS coronavirus SilentWitness Davos BB Hollyoaks',
#  'Dow falls more than  points amid first US case of coronavirus big decline in BoeingDJIA BA',
#  'Novel Coronavirus  Republic of Korea exChina   businesstravel travel',
#  'YOUS officials confirm first YOUS case of China coronavirus  via',
#  'Coronavirus is patented',
#  'First US case of Wuhan coronavirus confirmed by CDC',
#  'Passengers arriving at Chicagos OHare Airport will be screened for the deadly coronavirus now that an American h',
#  'bro the coronavirus made its way to the US',
#  'Theres an outbreak of a new coronavirus stemming from China and threatening to spread further',
#  'i will bring the netflix to your farm and we can hang out with the goats while everyone else gets the coronavirus',
#  'coronavirus deh bout yuh nuh read news',
#  'CDC confirms coronavirus',
#  'Novel Coronavirus  Situation Summary Wuhan China  CDC',
#  'CDC update on Novel Coronavirus',
#  'The CORONAVIRUS has reached the USA',
#  'There are media reports about a possible PH case of the coronavirus no official confirmation yet from  ho',
#  'NEW NorthKorea has reportedly shut it is borders to foreign tourists to keep out the mysterious new coronavirus',
#  'Ah this is just amazing seriously like and subscribe to this fucker CHEARS coronavirus',
#  'He arrived at SeattleTacoma Int Airport on January  before any health screenings for coronavirus began at US ai',
#  'Coronavirus may induce a chance to buy unrelated stocks at a discount Jim Cramer says  via CNBC news CNBC',
#  'China coronavirus What we know so far',
#  'Health officials confirm first YOUS case of China coronavirus expand screening',
#  'Coronavirus is hereWelcome to AmericaIt has begunPlease practice good personal  social HYGIENE',
#  'A mathematical model for simulating the transmission of Wuhan novel Coronavirus',
#  'UsIrancoronavirusdoomsday is looming ahead of us guys ',
#  'BAJA CALIFORNIA TOMA MEDIDAS PREVENTIVAS ANTE CASO DE CORONAVIRUS EN ESTADOSUNIDOS',
#  'OHare Screening For Wuhan Coronavirus After Hundreds Sickened Six Die In Asia',
#  'It is in SeattleCoronavirus What to know about the mysterious illness  FoxNews',
#  'st Case Of New Coronavirus Detected In YOUS',
#  'Prime Minister Scott Morrison says the coronavirus situation is evolving in Australia as passengers arriving into',
#  'Man fuck Hillary Clinton and the Coronavirus  period',
#  'THIS IS BS My mom had corona virus over a year ago and we are in the US Doctors told',
#  'A man in Washington State was diagnosed this week with the new Wuhan coronavirus the first case to be confirmed in',
#  'coronavirus  nypost How to avoid the deadly  Coronavirus now in the US',
#  'Oh Coronavirus is here na diay',
#  'Risk of coronavirus outbreak evolving as multiple Australianstested',
#  'Everything Jim Cramer said about the stock market on Mad Money including coronavirus uncertainty Costco CEO hi',
#  'My wife said something about a Corona Virus  I asked if was transmitted by the limes',
#  'so youre trying to tell me that coronavirus isnt just a made up sickness that frat boys contract after downing to',
#  'coronaviruswe need more semi literate semi functioning airport staff trying to take your temperature as you',
#  'YOUS begins airport screenings as coronavirus spreads inChina',
#  'talking about the Coronavirus Jamaica look out for this virus  ',
#  'CDC announces first US case of coronavirus that killed  in China',
#  'Washington state resident treated for coronavirus  Associated Press',
#  'Could Chinas New Coronavirus Become a Global Epidemic',
#  'MILLIONS AT RISK OF THE DEADLY CORONA VIRUS',
#  'st confirmed US case of new coronavirus reported in Washington state CDC',
#  'things to remember in light of the recent novel coronavirus outbreak note that emerging viruses are way more da',
#  'All you corona bitches stay away I heard yall got the coronavirus  moneyova',
#  'shoutout to all the racist grandparents who told their grandkids today to stay away from chinese people because of the coronavirus',
#  'This coronavirus thing looks like a scene',
#  'After learning that tooncies was driving for UberEats AndThenKarenSnapped uber BTSTOUR coronavirus',
#  'Globalpandemic here we come Deadly Chinese coronavirus arrives in US as Russia India  others boost border scre',
#  'China confirms  dead from coronavirus and  infected  via',
#  'Coronavirus LIVE At least nine dead as horror virus sweeps theglobe',
#  'Things you should know about the coronavirus outbreakhealth',
#  'We dying to Coronavirus',
#  'Comm This story shows breaking news connected to the Coronavirus outbreak in China and applies to an A',
#  'cases The  had better declare the outbreak of Coronavirus an International Health Emergency',
#  'Fuck its the coronavirus',
#  'Could Chinas New Coronavirus Become a GlobalEpidemic',
#  'If youre hoping the Coronavirus kills everyone its only because theres something in your life thats nagging at',
#  'The antidote to the coronavirus apparently',
#  'Achis achis por lo del coronavirus hermane',
#  'China coronavirus What we know so far  BBC News',
#  'SirCame to know about the coronavirus in ChinaI assume this is going to impact Chinas expor',
#  'Montreal hospitals on heightened alert following coronavirus warning',
#  'First case of Wuhan coronavirus confirmed in Snohomish County',
#  'Confused by all the talk about Coronavirus which EampP related company is that now',
#  'BREAKING Macau has reported its st case of novel coronavirus Hong Kong Economic Times reports Heres',
#  'st confirmed case of new coronavirus reported in US CDC',
#  'I Am sorry but who names these things Coronavirus Like comeon Is that just the hangover word for getting drunk off coronas',
#  'Xi Warns Party Officials Anyone Who Covers Up Coronavirus Will Be Nailed To Pillar Of ShameAs mi',
#  'Could Chinas New Coronavirus Become a GlobalEpidemic',
#  'Province asks healthcare staff to be vigilant in screening for possible coronavirus cases',
#  'CDC Confirms First US Case of Wuhan Coronavirus',
#  'LVSWYNNThe Macau Special Administrative Region Government Coordination Center for Novel Coronavirus Infection',
#  'Coronavirus reaches the US Everything we know about the deadly virus',
#  'Flu is in the move coronavirus',
#  'YOUS needs to quarantine all people traveling from China with Corona virus illness  You must not fail the public Assholes',
#  'coronavirus Update A table with updated information on cases  deaths and a map of cases in China etc Via',
#  'Sick Passengers on United Airlines Flight Examined by Health Officials Amid Coronavirus Fears',
#  'Will Not like this because I do not like it coronavirus is made by the Russians Iranians and North Koreans',
#  'English with Raymond Top News Item   CDC confirms first US case of Wuhan coronavirus  CNN',
#  'Watch s broadcast Come Talk With the Ladies DaAngels DaNation coronavirus Trump',
#  'BREAKING Coronavirus death toll rises to ninespectatorindex The Spectator Index',
#  'First US case of coronavirus confirmed in Washington state',
#  'Afrinews Report Cathay says cabin crew can wear masks on mainland   coronavirus',
#  'What is the difference between Coronavirus and Respiratory Syncytial Virus RSV',
#  'Life comes first for Matildas heading for coronavirus ground zero in China  via',
#  'Good to know coronavirus UAlberta',
#  'the existence of coronavirus implies the existence of a coronalightvirus',
#  'Airport thakugai corona virus ah screen kuran fashanvee vaguthu jehijje Dr Niyaf',
#  'China is grappling with a new coronavirus just as hundreds of millions prepare to travel during the Lunar New Year',
#  'The coronavirus is running the first page of THIS playbook Spy the double mutation and well be good',
#  'Reading about Chinas Coronavirus outbreak and the first thing that comes to mind is the Umbrella Corporation ',
#  'Do not worry they have already created the vaccine  US Patent for Coronavirus Patent Patent   i',
#  'It is lucky no confirmed coronavirus infection happens in Anhui Do not know how long it well endI remember I had h',
#  'New on Healthcare Economist Coronavirus lands in the US',
#  'Suspected coronavirus or whatever flulike symptoms that seem grave Since he traveled from Wushan it',
#  'Wuhan superspreader was having brain surgery  no symptoms of Coronavirus until later',
#  'China coronavirus Macau confirms first case as new disease looms over HongKong',
#  'I hope I dont have the coronavirus I dont even drink ',
#  'China confirms  people have now contracted deadly coronavirus',
#  'China Coronavirus Is Killing Global Stock Market and May Lead to Its Serious Correction  Blockchains',
#  'Could Chinas New Coronavirus Become a Global Epidemic',
#  'Humantohuman transmission confirmed in China coronavirus',
#  'Coronavirus outbreak China death toll rises to  pandemic fears mount  via',
#  'Coronavirus hits UnitedStates',
#  'Airport screenings for the Wuhan coronavirus increase around the world',
#  'China  coronavirus I hate Xi Jinping',
#  'Coronavirus Because I Am whatHumans',
#  'After a month of provarication CCP gotten round to be all show and no substance on Coronavirus Close Fish marke',
#  'First case of deadly Wuhan coronavirus confirmed in US',
#  'China confirms nine deaths as coronavirus spreads to multiple countries',
#  'Frustration over face masks as coronavirus cases in China climb to  nine dead as virus adapts and mutates',
#  'via  Key things to watch for in the coronavirus outbreak As the coronavirus outbreak continues key',
#  'Death toll from coronavirus rises to nine in China as pandemic fearsgrow',
#  'DMV airports not yet screening for coronavirus as more YOUS destinations begin checking for the disease',
#  'the coronavirus is in okinawa goodbye i am ACTUALLY going to die',
#  'Here is the first telescopic image of the Coronavirus',
#  'Chinese health official says new form of coronavirus could mutate spread further',
#  'Officials confirm first YOUS case of China coronavirus',
#  'There is no WWIII and the climate always changed At least the coronavirus is real but who the hell',
#  'BBC News  Coronavirus UK to monitor flights from China as precaution',
#  'BBC News  Coronavirus UK to monitor flights from China as precaution',
#  'New story on NPR Health Officials In China Say  Dead From Newly Identified Coronavirus',
#  'New story on NPR Health Officials In China Say  Dead From Newly Identified Coronavirus',
#  'Trump says he trusts Chinas Xi on coronavirus and the US has it totally under control here via',
#  'The top things medical experts know about the coronavirus MorningRushATL  via',
#  'CDC confirms first case of coronavirus in YOUS',
#  'Chinas ecommerce players look to ease new coronavirus fears by freezing prices for masks disinfectant',
#  'The first case of Chinalinked coronavirus reported in USA The case of the new coronavirus was confirmed in a man',
#  'Contributor  anticipates more coronavirus',
#  'Can we cancel Chinese New Year because of coronavirus and quarrantine the whole of Wuhan until this blows over',
#  'So Coronavirus now has  cases and   deathsThat is up from  cases and  deaths the same time yesterdayFo',
#  'The likelihood of Wuhan coronavirus infections in Finland is very low but we are monitoring the situation togeth',
#  'UK Coronavirus Heathrow to create separate arrival areaPrecautionary measure will apply to flights from regi',
#  'Trump says YOUS in great shape with plan for coronavirus',
#  'Health Authorities in Egypt  the WHO Put Highly Preventable Measures to STOP Coronavirus from entering Egypt',
#  'Why does Coronavirus have a patent Why does ANY virus have a patent Why is there a vaccine already being develop',
#  'Olympic boxing qualifiers in China nixed over coronavirus fears REVIEW Paris is back and she is got a cooking show',
#  'The Health secretary says there is still no confirmed case of the novel coronavirus in the country However a sena',
#  'Airlines Stocks To Sell As SARSlike coronavirus  Spreads',
#  'coronavirusThe infection is spreading one after another It is very dangerous Protect yourself',
#  'The Test a Deadly Coronavirus Outbreak Poses to Chinas Leadership',
#  'Reuters China confirms  cases of new coronavirus',
#  'Coronavirus has landed in the USA  Avoiding public objects is more important than ever  Get a Kooty Key and ramp',
#  'Bats likely origin of new coronavirus says study borneobulletin',
#  'days until I catch the coronavirus  going to smash a couple of crates of it',
#  'Impeachment Coronavirus Jeff Bezos Your Wednesday Briefing',
#  'Hong Kong on high alert after Wuhan coronavirus outbreak  Health',
#  'Deadly Coronavirus Outbreak Poses a Test to Chinas Leadership',
#  'Trump says US has plan to contain coronavirus',
#  'Hope you do not catch the Coronavirus while you out there',
#  'deadass thought that i have coronavirus because my friend keep on updating me about coronavirus',
#  'this corona virus is scaring me wtf wash your hands kids it helps you live longer',
#  'Newly identified strain of coronavirus has killed  people in China with  other confirmed infections health o',
#  'First Case Of Coronavirus Reaches US Health Officials Confirm',
#  'Wuhan coronavirus death toll rises to nine with  infected says China sparking fears of wider spread',
#  'Dear China You have given me more diseases than Tommy Lees given Pam AndersonSincerelyCanadaCoronavirus to hi',
#  'Chinascoronavirusposes no possible threat to Turkey We have in particular Quarantine rooms andinspection',
#  'Stocks DAX highs Daimler slows   shares rose on Wednesday on Chinas response to the coronavirus outbreak and',
#  'CDC confirms first US case of coronavirus that has killed  in China',
#  'Japan Struggling to Prepare for Coronavirus Threat',
#  'Coronavirus airports around the world carry out screenings',
#  'Health Officials In China Say  Dead From Newly Identified Coronavirus',
#  'Coronavirus Jumps Borders Hillary Unloads on Bernie  Harry Returns to Canada',
#  'Hospitals advised to prepare for dealing with Wuhan coronavirus  via',
#  'I have got chills they are multiplyingMust be that coronavirusGrease',
#  'Cases of new viral respiratory illness rise sharply in China from  confirmed Coronavirus cases as of mid',
#  'Reuters UK to tackle coronavirus with separate arrival area at Heathrow',
#  'Get yours today ImpeachmentTrialImpeachmentDayShamTrial coronavirus coronavirus GOPTraitors kubball',
#  'Coronavirus UK to monitor flights from China as precaution',
#  'I had coronavirus last year Miserable does not begin to describe it Had I been told it was more serious th',
#  'I had to delete a previous tweet in this thread stating no cases of the new coronavirus were picked up by border s',
#  'Have you encountered any precautionary measures for coronavirus',
#  'GHS initiates measures to prevent coronavirus outbreak in Ghana',
#  'China confirms nine deaths as coronavirus spreads to multiple countries',
#  'Be careful with that corona virus shit',
#  'What would Florence Nightingale say about this new coronavirus',
#  'Kenya steps up surveillance for coronavirus in all entry points passengers from China to be screened Acting Publi',
#  'chinese brings coronavirus in phnational government you all hear sumn',
#  'YOUS Canada ramp up coronavirus screening efforts after first reported case in Washington state',
#  'coronavirus is this the beginning of the depression',
#  'Newly added  cases of new coronavirus pneumonia in Hubei Wuhan with  total deaths  confirmed cases in',
#  'Coronavirus Expected to Spread in ChinaOverseas',
#  'Coronavirus North Korea closes border to foreigntourists',
#  'Coronavirus Outbreak Forces Chinese to Rethink Travel Plans',
#  'Latest  new cases of novel coronavirus have been confirmed in Hubei province bringing the total number in Chin',
#  'Death toll from new coronavirus outbreak in China reaches',
#  'Screenings to be conducted at Atlanta airport for coronavirus CDC says  via',
#  'Wuhan coronavirus death toll rises to nine with  infected says China sparking fears of wider spread  CNN',
#  'CDC Confirms First Case of Wuhan Coronavirus in the United States What Employers Need to Know   emplaw HR',
#  'Holy Fuck That Is  deaths in less than a daynCoV',
#  'Wait Does that have anything to do with the coronavirus',
#  'This Coronavirus is something serious Im watching every inbound flight coming from China',
#  'what are good steps to protect ourselves from the Coronavirus',
#  'if you put the puzzle pieces together the coronavirus really is going to be another plague i can smell it',
#  'Is no one else worried about that coronavirus  thats coming out of China Am I the only one scared because its li',
#  'BREAKING Death toll from coronavirus rises to  in China  NigeriaNews Nigeria',
#  'Newly Identified Coronavirus Has Killed  People Chinese Health Officials Say',
#  'like   person infected with coronavirus',
#  'Coronavirus Chinese officials advise against travel to Wuhan  ChinaVirus   ',
#  'Russia Suspects First Coronavirus Case  Reports',
#  'coronavirus explained simply',
#  'As Coronavirus Spreads Doctor says be Proactive but do not Panic',
#  'Hong Kong now reports two cases of the coronavirus in the city and tips on how to protect yourself',
#  'WE HAVE THE TECHNOLOGY MemeTeam Coronavirus',
#  'Let Us stop playin like we are not play plague inc and contain the corona virus smh',
#  'MyRepublica Russia is developing vaccine against coronavirus  RIA cites regulator',
#  'This article should read How AI will not  How AI could combat the spread of Chinas deadly coronavirus',
#  'Dr Bonnie Henry BECAUSEs Provincial Health Officer  will join us at   What do we need to know about the coronavirus',
#  'It is   of the clockI will be talking to  in todays show about the latest on the Wuhan coronavirus',
#  'The latest The BlogJunta Daily  coronavirus teamindia',
#  'Coronavirus weaker than Sars but may share link to bats Chinese scientists say  South China Morning Post',
#  'coronavirus  If it is true as I have read that infection may be well established in',
#  'Coronavirus Death Toll in China Rises as YOUS Airports Screen Passengers',
#  'I Do Not Know who needs thisJust in case you are interested in the coronavirus newsHere is the link to the live update on the',
#  'USs first case of Novel Coronavirus confirmed in Snohomish County Washington Stay informed by following the CDC',
#  'Coronavirus is spreading rapidly in China  deaths so far  people infected',
#  'I got food poisoning im going to die I got the Corona Virus ',
#  'Really lots of people order bats soup and bats are spreaders of coronavirus',
#  'Coronavirus is that when youve had too many Coronas',
#  'Maybe theyll give you Chinese coronavirus',
#  'US puts up coronavirus shield ALL passengers from Wuhan to be funneled to screening system at five major airport',
#  'The Wuhan Coronavirus Outbreak Hits Korea',
#  'I have discovered the cure to coronavirus Lime wedge',
#  'Death toll from the new coronavirus outbreak in China increases to  with confirmed cases of infect',
#  'die from Chinas coronavirus over  affected amid global fears',
#  'Here is what NH health officials and doctors are saying as the world closely watches the spread of the coronavirus',
#  'New coronavirus airports on alert AFP',
#  'Its probably not named yet because its new so they are just calling it coronavirus There are a handful of others',
#  'Coronavirus Desfronterzate',
#  'australia on fireWWgun girl shitting herselfcoronavirus choose your fighter which one will cause the end of the world',
#  'This cannot be good publicity for coronavirus',
#  'What we know and do not know about coronavirus  via',
#  'What science knows about coronavirus',
#  'Coronavirus came just in time to fulfill there being a major disease every  It also comes on the eve of Lunar N',
#  'Do not mean to make light of the coronavirus but I think I had that a few years back the day after Cinco De Mayo',
#  'Coronavirus cure Can you treat coronavirus How dangerous is it',
#  'USDJPY coronavirus stoploss',
#  'WHO officials hold news conference on the coronavirusoutbreak',
#  'China coronavirus deaths rise to  heightening global alarm',
#  'Newly Identified Coronavirus Has Killed  People Chinese Health Officials Say',
#  'Corona virus several deaths in China  Switzerland isprepared',
#  'By Iquria RaymeA recent outbreak of the deadly coronavirus has sparked an emergency health crisis to all traveler',
#  'Opening an AliExpress package and getting hit with a belt of fresh Coronavirus',
#  'Please contact this Sidha doctor in TAMILNADUIndiaFor treatmentCoronavirusFree of costPlease in',
#  'Chilling dispatch from Coronavirus ground zero reveals apocalyptic scenes as killer bug turns Wuhan into a ghost to',
#  'Coronavirus Epidemic Emphasizes the Need to Buy Gold  Turn your home computer into a Bitc',
#  'Wuhan coronavirus spreads from China to US in Washington state',
#  'What was I saying about processed meat from China  the Wuhan coronavirus Yep',
#  'Deadly coronavirus killing people in China might already be in the UK Heathrow passengers to be isolated',
#  'Please will someone with that Coronavirus please come and lips me Proper cant be arsed with work tomorrow',
#  'Deaths from coronavirus infections double hospitals overwhelmed',
#  'salvinicitofona earthquake BabesMampintsha OProblemaDoBrasileiroE coronavirus MapOfTheSoulTour pettifogging',
#  'Coronavirus death toll rises to  with  infected in China as experts warn mutating bug could spread further',
#  'What is the new coronavirus',
#  'All day long I see tweets about Coronavirus and tweets about contaminated wells in Kazakhstan The g',
#  'Tremble puny humans the end is nigh the day of reckoning is close thanks to this Coronavirus or at least I hope i',
#  'Chinas Coronavirus is Much Worse Than You Think  ChinaPneumonia coronavirus ChinaVirus',
#  'The death toll and confirmed cases of the Wuhan coronavirus is rising sharply We will hear how officials in Canada',
#  'An extraordinary responseWuhan nCoV',
#  'Do not matter the mask is black or white The mask that let out Coronavirus is the Communist mask',
#  'Wuhan coronavirus outbreak kills  in China as first case found in US',
#  'Travel From Chinese City at Center of Virus Outbreak Halted coronavirus',
#  'Coronavirus ALL Passengers WuhangtUS Funneled to  Airports for ScreeningLosAngelesLAX NewYorkJFK',
#  'Chinese Authorities Cut Off Transportation From Wuhan Center of Coronavirus Outbreak',
#  ' China confirms  deaths as coronavirus spreads to multiple countries',
#  'At least  dead as Chinese coronavirus spreads despite efforts to contain it',
#  'Professor Warns New Coronavirus Has Same Kill Rate as the Spanish Flu  Breaking News from NewsWars  Share all',
#  'coronavirus In other words it is a fullfledged quarantine',
#  'BREAKING Chinese city shuts public transport amid coronavirus outbreak',
#  'Indian Students In Chinas Wuhan In Anxious Wait As Coronavirus TurnsVirulent',
#  'Watch s broadcast Emergency committee on coronavirus outbreak',
#  'coronavirus stocks gaining traction ICCC ALT LAKE APT NVAX potential gap plays for tomorrow',
#  'Chinese state media says the city of Wuhan is shutting down outbound flights and trains as a new coronavirus s',
#  'Oh good theres a confirmed case of Wuhan corona virus the Seattle area',
#  'A touch of Coronavirus',
#  'China Silences Critics Over CoronavirusOutbreak',
#  'A virus with no vaccine that can cause pneumonia is my living nightmare coronavirus',
#  'Wuhan  Coronavirus hit Chinese city of  million people to shut public transport Airport train stations bus',
#  'Okay how serious is the Coronavirus I thought it was similar to the flu but clearly I am wrong',
#  'GOVX Corona Virus Effect',
#  'How did the coronavirus get its name and what will it do to the demand for corona beer',
#  'Professor Warns New Coronavirus Has Same Kill Rate as the Spanish Flu',
#  'Chinese authorities to cut off city of  million to contain coronavirus  WashingtonExaminer',
#  'Wuhan on lockdown Coronavirus China to halt all transport out of Wuhan as death toll reaches',
#  'Coronavirus infections in China feared to be more widespread than officially reported Wuhan closes transport netwo',
#  'US forces passengers from Wuhan China to get screened for coronavirus  via',
#  'As coronavirus fatalities mount China and other countries will have to take more drastic measures to contain the',
#  'Finding out the coronavirus originated from Wuhan and knowing wayv boys were there before just scares me',
#  'is the American coronavirus of the  world He is killing everything and everyone slowly but surely',
#  'New coronavirus not yet a global health concern World Health Organization says  via',
#  'Wuhan China shutting down transportation to limit transmission of new coronavirus coronavirus BChealth',
#  'Wuhan population  million China  billion  infected and  deaths corona virus not nice but scaremongering is worse',
#  'US forces passengers from Wuhan China to get screened for coronavirus']

# %% [markdown]
# ## Setting Sentiment Scores

# %%
# Used to get sentiment score for the predictions
def sentiment_score(negative, neutral, positive):
    # Finds positive/negative difference returning a value between -1 to 1
    score = positive - negative
    # This is normalized to the range 0 to 1 because it's simpler to divide the sentiments into 5 parts between 0 and 1
    normalized_score = (score + 1) / 2
    # Round the score to 4 decimal places
    normalized_score = round(normalized_score, 4)
    return normalized_score

# %%
possible_sentiment_values = [0.25, 0.5, 0.75]

# Round values to sentiment values
def closest_value(sent_score):
    return min(possible_sentiment_values, key=lambda x: abs(sent_score - x))

# %%
# Used to get categorize sentiment score for the training data
def categorize_sentiment(score):
    if score == "neg":
        return 0.25
    elif score == "neg":
        return 0.25
    elif score == "neu":
        return 0.5
    elif score == "pos":
        return 0.75
    else:
        return 0.75

# %%
# Test Data Sentiment Score List
test_sentiment_scores = []
test_sentiments = test_data_df['label'].to_list()

for sentiment in test_sentiments:
    sent_score = categorize_sentiment(sentiment)
    test_sentiment_scores.append(sent_score)

# %%
len(test_sentiments)
# Out:
# 500

# %% [markdown]
# ## Performing BERT Sentiment Analysis

# %%
# Function used to convert the texts to what is needed:
# - turn the text into tensors
# - truncate and pad the tweets to 280 characters
def analyze_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=280)
    outputs = model(**inputs)
    logits = outputs.logits
    probabilities = torch.nn.functional.softmax(logits, dim=1)
    return probabilities

# %%
# Loads BERT tokenizer and model from a BERT model pre-trained on emotion dataset
# Found here: https://huggingface.co/finiteautomata/bertweet-base-sentiment-analysis
# This was based off of BERTweet which can be found here: https://github.com/VinAIResearch/BERTweet?tab=readme-ov-file
# The model was then trained with SemEval 2017 corpus (around ~40k tweets) to refine sentiment
tokenizer = AutoTokenizer.from_pretrained('finiteautomata/bertweet-base-sentiment-analysis')
model = AutoModelForSequenceClassification.from_pretrained('finiteautomata/bertweet-base-sentiment-analysis')

# %%
# Sentiments list
sentiments = ["negative", "neutral", "positive"]

# %%
# Predicting sentiment for the individual tweets
test_sentiment_predictions = []
for doc in pruned_docs:
    # Getting probabilities
    probabilities = analyze_sentiment(doc)

    # Saving the probabilities to respective variables
    negative_score = probabilities[0][0].item()
    neutral_score = probabilities[0][1].item()
    positive_score = probabilities[0][2].item()
    
    # Getting an overall sentiment score
    pred_sent_score = sentiment_score(negative_score, neutral_score, positive_score)
    categorized_sent_score = closest_value(pred_sent_score)
    test_sentiment_predictions.append(categorized_sent_score)

# %% [markdown]
# ## Evaluation Methods

# %%
test_sentiment_predictions
# Out:
# [0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.75,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.75,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.25,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.75,
#  0.75,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.75,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.75,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.75,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25]

# %%
test_sentiment_scores
# Out:
# [0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.75,
#  0.5,
#  0.25,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.25,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.25,
#  0.25,
#  0.5]

# %%
# Calculates the list of absolute differences
differences = [abs(a - b) for a, b in zip(test_sentiment_predictions, test_sentiment_scores)]

# Calculates the total differences
count_equal = sum(a == b for a, b in zip(test_sentiment_predictions, test_sentiment_scores))

# %%
difference_avg = sum(differences) / len(differences)

# %%
difference_avg
# Out:
# 0.1045

# %%
count_equal
# Out:
# 301
